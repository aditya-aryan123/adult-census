# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('frame.csv')

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90   Private   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66   Private  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0  Machine-op-inspct  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2       Adm-clerical      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'State-gov', 'Federal-gov', 'Self-emp-not-inc',
#        'Self-emp-inc', 'Local-gov', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df['workclass'].value_counts(normalize=True)*100
# Out:
# Private             74.073278
# Self-emp-not-inc     8.246061
# Local-gov            6.731980
# State-gov            4.176776
# Self-emp-inc         3.605540
# Federal-gov          3.098799
# Without-pay          0.046067
# Never-worked         0.021498
# Name: workclass, dtype: float64

# %%
pd.crosstab(df['workclass'], df['income'])
# Out:
# income            <=50K  >50K
# workclass
# Federal-gov         630   379
# Local-gov          1556   636
# Never-worked          7     0
# Private           19041  5078
# Self-emp-inc        533   641
# Self-emp-not-inc   1940   745
# State-gov           998   362
# Without-pay          15     0

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(pd.crosstab(df['workclass'], df['income']), annot=True, fmt='.5g')
plt.show()

# %%
pd.crosstab(df['workclass'], df['income']).plot(kind='bar', stacked=True, figsize=(15, 6))
plt.show()

# %%
df['workclass'].replace({'Without-pay': 'Other', 'Never-worked': 'Other'}, inplace=True)

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'State-gov', 'Federal-gov', 'Self-emp-not-inc',
#        'Self-emp-inc', 'Local-gov', 'Other'], dtype=object)

# %%
df['education'].unique()
# Out:
# array(['HS-grad', 'Some-college', '7th-8th', '10th', 'Doctorate',
#        'Prof-school', 'Bachelors', 'Masters', '11th', 'Assoc-acdm',
#        'Assoc-voc', '1st-4th', '5th-6th', '12th', '9th', 'Preschool'],
#       dtype=object)

# %%
df.groupby('education')['income'].value_counts().sort_values(ascending=False)
# Out:
# education     income
# HS-grad       <=50K     8826
# Some-college  <=50K     5904
# Bachelors     <=50K     3134
#               >50K      2221
# HS-grad       >50K      1675
# Some-college  >50K      1387
# 11th          <=50K     1115
# Assoc-voc     <=50K     1021
# Masters       >50K       959
# 10th          <=50K      871
# Assoc-acdm    <=50K      802
# Masters       <=50K      764
# 7th-8th       <=50K      606
# 9th           <=50K      487
# Prof-school   >50K       423
# 12th          <=50K      400
# Assoc-voc     >50K       361
# 5th-6th       <=50K      317
# Doctorate     >50K       306
# Assoc-acdm    >50K       265
# 1st-4th       <=50K      162
# Prof-school   <=50K      153
# Doctorate     <=50K      107
# 10th          >50K        62
# 11th          >50K        60
# Preschool     <=50K       51
# 7th-8th       >50K        40
# 12th          >50K        33
# 9th           >50K        27
# 5th-6th       >50K        16
# 1st-4th       >50K         6
# ...

# %%
df.groupby('education')['income'].value_counts().plot(figsize=(15, 6))
# Out:
# <AxesSubplot:xlabel='education,income'>

# %%
pd.crosstab(df['education'], df['income'])
# Out:
# income        <=50K  >50K
# education
# 10th            871    62
# 11th           1115    60
# 12th            400    33
# 1st-4th         162     6
# 5th-6th         317    16
# 7th-8th         606    40
# 9th             487    27
# Assoc-acdm      802   265
# Assoc-voc      1021   361
# Bachelors      3134  2221
# Doctorate       107   306
# HS-grad        8826  1675
# Masters         764   959
# Preschool        51     0
# Prof-school     153   423
# Some-college   5904  1387

# %%
pd.crosstab(df['education'], df['income']).plot(kind='bar', stacked=True, figsize=(15, 6))
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(pd.crosstab(df['education'], df['income']), annot=True, fmt='.5g')
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='education', hue='income', kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
df['marital.status'].unique()
# Out:
# array(['Widowed', 'Divorced', 'Separated', 'Never-married',
#        'Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse'],
#       dtype=object)

# %%
df['marital.status'].value_counts(normalize=True)*100
# Out:
# Married-civ-spouse       45.993673
# Never-married            32.809189
# Divorced                 13.645158
# Separated                 3.147938
# Widowed                   3.049661
# Married-spouse-absent     1.283744
# Married-AF-spouse         0.070637
# Name: marital.status, dtype: float64

# %%
pd.crosstab(df['marital.status'], df['income'])
# Out:
# income                 <=50K  >50K
# marital.status
# Divorced                3980   463
# Married-AF-spouse         13    10
# Married-civ-spouse      8284  6692
# Married-spouse-absent    384    34
# Never-married          10192   491
# Separated                959    66
# Widowed                  908    85

# %%
pd.crosstab(df['marital.status'], df['income']).plot(kind='bar', stacked=True, figsize=(15, 6))
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(pd.crosstab(df['marital.status'], df['income']), annot=True, fmt='.5g')
plt.show()

# %%
single = ['Never-married', 'Divorced', 'Separated', 'Married-spouse-absent', 'Married-AF-spouse']
df['Marital_Status'] = np.where(df['marital.status'].isin(single), 'Single', 'Married')

# %%
df['Marital_Status'].value_counts()
# Out:
# Single     16592
# Married    15969
# Name: Marital_Status, dtype: int64

# %%
pd.crosstab(df['Marital_Status'], df['income'])
# Out:
# income          <=50K  >50K
# Marital_Status
# Married          9192  6777
# Single          15528  1064

# %%
pd.crosstab(df['Marital_Status'], df['income']).plot(kind='bar', stacked=True, figsize=(15, 6))
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(pd.crosstab(df['Marital_Status'], df['income']), annot=True, fmt='.5g')
plt.show()

# %%
df['occupation'].unique()
# Out:
# array(['Machine-op-inspct', 'Exec-managerial', 'Adm-clerical',
#        'Prof-specialty', 'Other-service', 'Craft-repair',
#        'Transport-moving', 'Handlers-cleaners', 'Sales',
#        'Farming-fishing', 'Protective-serv', 'Tech-support',
#        'Armed-Forces', 'Priv-house-serv'], dtype=object)

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='occupation', hue='income', kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
df['native.country'].value_counts(normalize=True) * 100
# Out:
# United-States                 91.090568
# Mexico                         2.020822
# Philippines                    0.660299
# Germany                        0.420749
# Canada                         0.371610
# Puerto-Rico                    0.356254
# El-Salvador                    0.334756
# India                          0.325543
# Cuba                           0.294831
# England                        0.276404
# South                          0.267191
# Jamaica                        0.251835
# China                          0.239550
# Vietnam                        0.227266
# Italy                          0.224195
# Dominican-Republic             0.221123
# Guatemala                      0.202696
# Japan                          0.193483
# Poland                         0.187341
# Columbia                       0.184270
# Taiwan                         0.168914
# Iran                           0.144344
# Haiti                          0.135131
# ...

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='native.country', hue='income', kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
pd.crosstab(df['native.country'], df['income']).plot(kind='bar', stacked=True, figsize=(15, 6))
plt.show()

# %%
pd.crosstab(df['native.country'], df['income'])
# Out:
# income                      <=50K  >50K
# native.country
# Cambodia                       14     7
# Canada                         82    39
# China                          57    21
# Columbia                       58     2
# Cuba                           71    25
# Dominican-Republic             70     2
# Ecuador                        24     4
# El-Salvador                   100     9
# England                        60    30
# France                         18    12
# Germany                        93    44
# Greece                         21     8
# Guatemala                      63     3
# Haiti                          40     4
# Holand-Netherlands              1     0
# Honduras                       12     1
# Hong                           16     8
# Hungary                        10     3
# India                          62    44
# Iran                           27    20
# Ireland                        19     5
# Italy                          48    25
# ...

# %%
plt.figure(figsize=(15, 20))
sns.heatmap(pd.crosstab(df['native.country'], df['income']), annot=True, fmt='.5g')
plt.show()

# %%
percentage_threshold = 0.3
arr_others = df['native.country'].value_counts()[df['native.country'].value_counts(normalize=True)*100 < percentage_threshold].index
df['native.country'].replace(to_replace=arr_others, value = ['others']*len(arr_others), inplace=True)

# %%
import matplotlib.gridspec as gridspec

# %%
cat_cols = [col for col in df.columns if df[col].dtypes == 'object']
target = 'income'
total = len(df)

grid = gridspec.GridSpec(10, 1)
plt.figure(figsize=(17, 35))

for n, col in enumerate(df[cat_cols]): 
    tmp = pd.crosstab(df[col], df[target], normalize='index') * 100
    tmp = tmp.reset_index()
    tmp.rename(columns={0:'<=50K', 1:'>50K'}, inplace=True)

    ax = plt.subplot(grid[n])
    sns.countplot(x=col, data=df, order=list(tmp[col].values) , palette='Set1') 
    ax.set_ylabel('Count', fontsize=15)
    ax.set_title(f'{col} Distribution by Target', fontsize=18)
    ax.set_xlabel(f'{col} values', fontsize=15)
    gt = ax.twinx()
    gt = sns.pointplot(x=col, y='>50K', data=tmp,
                        order=list(tmp[col].values),
                        color='black', legend=False)
    gt.set_ylim(tmp['>50K'].min()-5,tmp['>50K'].max()*1.1)
    gt.set_ylabel("Target %True(1)", fontsize=16)
    sizes=[]
    for p in ax.patches:
        height = p.get_height()
        sizes.append(height)
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(height/total*100),
                ha="center", fontsize=14) 
    ax.set_ylim(0, max(sizes) * 1.15)


plt.subplots_adjust(hspace=0.1, wspace=0.3)
plt.tight_layout()
plt.show()

# %%
num_cols = [col for col in df.columns if df[col].dtypes in ['int64', 'int32']]
target = 'income'
total = len(df)

grid = gridspec.GridSpec(10, 1)
plt.figure(figsize=(17, 35))

for n, col in enumerate(df[num_cols]): 
    tmp = pd.crosstab(df[col], df[target], normalize='index') * 100
    tmp = tmp.reset_index()
    tmp.rename(columns={0:'<=50K', 1:'>50K'}, inplace=True)

    ax = plt.subplot(grid[n])
    sns.countplot(x=col, data=df, order=list(tmp[col].values) , palette='Set1') 
    ax.set_ylabel('Count', fontsize=15)
    ax.set_title(f'{col} Distribution by Target', fontsize=18)
    ax.set_xlabel(f'{col} values', fontsize=15)
    gt = ax.twinx()
    gt = sns.pointplot(x=col, y='>50K', data=tmp,
                        order=list(tmp[col].values),
                        color='black', legend=False)
    gt.set_ylim(tmp['>50K'].min()-5,tmp['>50K'].max()*1.1)
    gt.set_ylabel("Target %True(1)", fontsize=16)
    sizes=[]
    for p in ax.patches:
        height = p.get_height()
        sizes.append(height)
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(height/total*100),
                ha="center", fontsize=14) 
    ax.set_ylim(0, max(sizes) * 1.15)


plt.subplots_adjust(hspace=0.1, wspace=0.3)
plt.tight_layout()
plt.show()

# %%
df.loc[df['capital.loss'] > 0, ['capital.loss']].plot(kind='hist', figsize=(15, 6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['capital.loss'].describe()
# Out:
# count    32561.000000
# mean        87.303830
# std        402.960219
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital.loss, dtype: float64

# %%
plt.figure(figsize=(15, 6))
sns.kdeplot(data=df, x='capital.loss')
# Out:
# <AxesSubplot:xlabel='capital.loss', ylabel='Density'>

# %%
plt.figure(figsize=(15, 6))
sns.catplot(data=df, y='capital.loss', x='income')

# %%
df['capital.gain'].unique()
# Out:
# array([    0, 99999, 41310, 34095, 27828, 25236, 25124, 22040, 20051,
#        18481, 15831, 15024, 15020, 14344, 14084, 13550, 11678, 10605,
#        10566, 10520,  9562,  9386,  8614,  7978,  7896,  7688,  7443,
#         7430,  7298,  6849,  6767,  6723,  6514,  6497,  6418,  6360,
#         6097,  5721,  5556,  5455,  5178,  5060,  5013,  4934,  4931,
#         4865,  4787,  4687,  4650,  4508,  4416,  4386,  4101,  4064,
#         3942,  3908,  3887,  3818,  3781,  3674,  3471,  3464,  3456,
#         3432,  3418,  3411,  3325,  3273,  3137,  3103,  2993,  2977,
#         2964,  2961,  2936,  2907,  2885,  2829,  2653,  2635,  2597,
#         2580,  2538,  2463,  2414,  2407,  2387,  2354,  2346,  2329,
#         2290,  2228,  2202,  2176,  2174,  2105,  2062,  2050,  2036,
#         2009,  1848,  1831,  1797,  1639,  1506,  1471,  1455,  1424,
#         1409,  1173,  1151,  1111,  1086,  1055,   991,   914,   594,
#          401,   114], dtype=int64)

# %%
f_ = df['capital.gain'].value_counts().reset_index()

# %%
f_.nlargest(n=10, columns='capital.gain')
# Out:
#    index  capital.gain
# 0      0         29849
# 1  15024           347
# 2   7688           284
# 3   7298           246
# 4  99999           159
# 5   5178            97
# 6   3103            97
# 7   4386            70
# 8   5013            69
# 9   8614            55

# %%
f_['capital.gain'].unique()
# Out:
# array([29849,   347,   284,   246,   159,    97,    70,    69,    55,
#           53,    48,    43,    42,    41,    37,    34,    32,    31,
#           27,    26,    25,    24,    23,    22,    20,    19,    17,
#           16,    15,    14,    12,    11,     9,     8,     7,     6,
#            5,     4,     3,     2,     1], dtype=int64)

# %%
f_.loc[f_['capital.gain'] > 11, :]
# Out:
#     index  capital.gain
# 0       0         29849
# 1   15024           347
# 2    7688           284
# 3    7298           246
# 4   99999           159
# 5    5178            97
# 6    3103            97
# 7    4386            70
# 8    5013            69
# 9    8614            55
# 10   3325            53
# 11   2174            48
# 12  10520            43
# 13   4064            42
# 14   4650            41
# 15  14084            41
# 16  20051            37
# 17   3137            37
# 18    594            34
# 19  27828            34
# 20   3908            32
# 21   2829            31
# 22  13550            27
# 23   6849            27
# 24  14344            26
# 25   1055            25
# 26   3411            24
# 27   2885            24
# 28   3464            23
# 29   2176            23
# 30   4787            23
# 31   9386            22
# 32   4101            20
# 33   2597            20
# 34   2407            19
# 35   4865            17
# 36   2202            16
# ...

# %%
plt.figure(figsize=(15, 6))
sns.pointplot(data=df, y='capital.gain', x='income')
# Out:
# <AxesSubplot:xlabel='income', ylabel='capital.gain'>

# %%
df['capital.gain_indicator'] = np.where(df['capital.gain'] > 0, 1, 0)

# %%
df['capital.loss_indicator'] = np.where(df['capital.loss'] > 0, 1, 0)

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=df, x='capital.gain_indicator', hue='income')
# Out:
# <AxesSubplot:xlabel='capital.gain_indicator', ylabel='count'>

# %%
df['gain/loss'] = np.where((df['capital.gain'] > 0) | (df['capital.loss'] > 0), 1, -1)

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=df, x='gain/loss', hue='income')
# Out:
# <AxesSubplot:xlabel='gain/loss', ylabel='count'>

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90   Private   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66   Private  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0  Machine-op-inspct  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2       Adm-clerical      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income Marital_Status  \
# 0          4356              40  United-States  <=50K        Married
# ...

# %%
df['age'].sort_values(ascending=False).unique()
# Out:
# array([90, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78, 77, 76, 75, 74, 73,
#        72, 71, 70, 69, 68, 67, 66, 65, 64, 63, 62, 61, 60, 59, 58, 57, 56,
#        55, 54, 53, 52, 51, 50, 49, 48, 47, 46, 45, 44, 43, 42, 41, 40, 39,
#        38, 37, 36, 35, 34, 33, 32, 31, 30, 29, 28, 27, 26, 25, 24, 23, 22,
#        21, 20, 19, 18, 17], dtype=int64)

# %%
bins = [0, 18, 25, 35, 50, 65, 90]
labels = ['0-17', '18-24', '25-34', '35-49', '50-64', '65+']

df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, include_lowest=True)

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=df, x='age_group', hue='income')
# Out:
# <AxesSubplot:xlabel='age_group', ylabel='count'>

# %%
sns.histplot(data=df, x='age', hue='income', kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.pointplot(data=df, x='age', y='income')
# Out:
# <AxesSubplot:xlabel='age', ylabel='income'>

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90   Private   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66   Private  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=df, x='occupation', hue='income')
# Out:
# <AxesSubplot:xlabel='occupation', ylabel='count'>

# %%
workclass_map = {
    'Private': 'Private',
    'Self-emp-not-inc': 'Self-employed',
    'Self-emp-inc': 'Self-employed',
    'Federal-gov': 'Government',
    'Local-gov': 'Government',
    'State-gov': 'Government',
    'Without-pay': 'Unemployed',
    'Never-worked': 'Unemployed'
}
df['workclass_group'] = df['workclass'].map(workclass_map)

# %%
education_map = {
    'Preschool': 'No-schooling',
    '1st-4th': 'Elementary-school',
    '5th-6th': 'Elementary-school',
    '7th-8th': 'Middle-school',
    '9th': 'High-school',
    '10th': 'High-school',
    '11th': 'High-school',
    '12th': 'High-school',
    'HS-grad': 'High-school',
    'Some-college': 'Some-college',
    'Assoc-voc': 'Associates',
    'Assoc-acdm': 'Associates',
    'Bachelors': 'Bachelors',
    'Masters': 'Masters',
    'Prof-school': 'Prof-school',
    'Doctorate': 'Doctorate'
}
df['education_group'] = df['education'].map(education_map)

# %%
df['capital_diff'] = df['capital.gain'] - df['capital.loss']

# %%
df['occupation'].unique()
# Out:
# array(['Machine-op-inspct', 'Exec-managerial', 'Adm-clerical',
#        'Prof-specialty', 'Other-service', 'Craft-repair',
#        'Transport-moving', 'Handlers-cleaners', 'Sales',
#        'Farming-fishing', 'Protective-serv', 'Tech-support',
#        'Armed-Forces', 'Priv-house-serv'], dtype=object)

# %%
pd.set_option('display.max_columns', 22)
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90   Private   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66   Private  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df['income_int'] = np.where(df['income'] == '>50K', 1, 0)

# %%
df['age_per_hour'] = df['age'] * df['hours.per.week']

# %%
pd.set_option('display.max_columns', 26)
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90   Private   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66   Private  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32561 non-null  int64
#  1   workclass               32561 non-null  object
#  2   fnlwgt                  32561 non-null  int64
#  3   education               32561 non-null  object
#  4   education.num           32561 non-null  int64
#  5   marital.status          32561 non-null  object
#  6   occupation              32561 non-null  object
#  7   relationship            32561 non-null  object
#  8   race                    32561 non-null  object
#  9   sex                     32561 non-null  object
#  10  capital.gain            32561 non-null  int64
#  11  capital.loss            32561 non-null  int64
#  12  hours.per.week          32561 non-null  int64
#  13  native.country          32561 non-null  object
# ...

# %%
cat_cols = [col for col in df_copy.columns if df_copy[col].dtypes == 'object']
cat_cols = cat_cols + ['age_group']
cat_cols
# Out:
# ['workclass',
#  'marital.status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native.country',
#  'Marital_Status',
#  'workclass_group',
#  'education_group',
#  'age_group']

# %%
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
from statsmodels.api import Logit

# %%
one_hot_list = ['workclass_group', 'marital.status', 'relationship', 
                'race', 'sex', 'age_group']
label_encode_list = ['native.country', 'Marital_Status', 'occupation', 'education_group', 'workclass']

# %%
df_copy = df.copy()
df_copy.drop(['income', 'education', 'age', 'fnlwgt'], axis=1, inplace=True)

# %%
list_ = df_copy = pd.get_dummies(data=df_copy, columns=one_hot_list)

# %%
list_ = one_hot_list + label_encode_list

# %%
for col in cat_cols:
    le = LabelEncoder()
    df_copy.loc[:, col] = le.fit_transform(df_copy[col])

# %%
X = df_copy.drop('income_int', axis=1)
y = df_copy['income_int']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   workclass               32561 non-null  int32
#  1   education.num           32561 non-null  int64
#  2   marital.status          32561 non-null  int32
#  3   occupation              32561 non-null  int32
#  4   relationship            32561 non-null  int32
#  5   race                    32561 non-null  int32
#  6   sex                     32561 non-null  int32
#  7   capital.gain            32561 non-null  int64
#  8   capital.loss            32561 non-null  int64
#  9   hours.per.week          32561 non-null  int64
#  10  native.country          32561 non-null  int32
#  11  Marital_Status          32561 non-null  int32
#  12  capital.gain_indicator  32561 non-null  int32
#  13  capital.loss_indicator  32561 non-null  int32
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 32561 entries, 0 to 32560
# Series name: income_int
# Non-Null Count  Dtype
# --------------  -----
# 32561 non-null  int32
# dtypes: int32(1)
# memory usage: 127.3 KB

# %%
for col in X.columns:
    scaler = StandardScaler()
    X.loc[:, col] = scaler.fit_transform(X[col].values.reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
#       1 for col in X.columns:
#       2     scaler = StandardScaler()
# ----> 3     X.loc[:, col] = scaler.fit_transform(X[col].values.reshape(-1, 1))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
#     870     return self.fit(X, y, **fit_params).transform(X)
#
# ...

# %%
y.unique()
# Out:
# array([0, 1])

# %%
X
# Out:
#        workclass  education.num  marital.status  occupation  relationship  \
# 0              3              9               6           6             1
# 1              3              9               6           3             1
# 2              3             10               6           0             4
# 3              3              4               0           6             4
# 4              3             10               5           9             3
# ...          ...            ...             ...         ...           ...
# 32556          3             10               4          10             1
# 32557          3             12               2          12             5
# 32558          3              9               2           6             0
# 32559          3              9               6           0             4
# 32560          3              9               4           0             3
#
#        race  sex  capital.gain  capital.loss  hours.per.week  native.country  \
# ...

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
svc = SVC()
svc.fit(X_train, y_train)
pred = svc.predict(X_test)

# %%
print(confusion_matrix(pred, y_test))
print(classification_report(pred, y_test))
# Out:
# [[6040 1427]
#  [ 109  565]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.81      0.89      7467
#            1       0.28      0.84      0.42       674
#
#     accuracy                           0.81      8141
#    macro avg       0.63      0.82      0.66      8141
# weighted avg       0.92      0.81      0.85      8141

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# %%
reg = RandomForestClassifier()
reg.fit(X_train, y_train)
pred = reg.predict(X_test)

# %%
print(confusion_matrix(pred, y_test))
print(classification_report(pred, y_test))
# Out:
# [[5683  716]
#  [ 466 1276]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91      6399
#            1       0.64      0.73      0.68      1742
#
#     accuracy                           0.85      8141
#    macro avg       0.78      0.81      0.79      8141
# weighted avg       0.86      0.85      0.86      8141

# %%
importance_ = reg.feature_importances_

# %%
imp_frame = pd.DataFrame(importance_, index=X.columns)
imp_frame.rename(columns={0: 'Feature Importance'}, inplace=True)
imp_frame = imp_frame.reset_index()

# %%
plt.figure(figsize=(15, 6))
sns.barplot(data=imp_frame, x='index', y='Feature Importance')
plt.xticks(rotation=90)
plt.show()

# %%
etc = ExtraTreesClassifier()
etc.fit(X_train, y_train)
pred = etc.predict(X_test)

# %%
print(confusion_matrix(pred, y_test))
print(classification_report(pred, y_test))
# Out:
# [[5647  741]
#  [ 502 1251]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      6388
#            1       0.63      0.71      0.67      1753
#
#     accuracy                           0.85      8141
#    macro avg       0.77      0.80      0.78      8141
# weighted avg       0.86      0.85      0.85      8141

# %%
importance_ = etc.feature_importances_

# %%
imp_frame = pd.DataFrame(importance_, index=X.columns)
imp_frame.rename(columns={0: 'Feature Importance'}, inplace=True)
imp_frame = imp_frame.reset_index()

# %%
plt.figure(figsize=(15, 6))
sns.barplot(data=imp_frame, x='index', y='Feature Importance')
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(max_iter=10000)
logreg.fit(X_train, y_train)
pred = logreg.predict(X_test)

# %%
print(confusion_matrix(pred, y_test))
print(classification_report(pred, y_test))
# Out:
# [[5775  853]
#  [ 374 1139]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.90      6628
#            1       0.57      0.75      0.65      1513
#
#     accuracy                           0.85      8141
#    macro avg       0.76      0.81      0.78      8141
# weighted avg       0.87      0.85      0.86      8141

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, HistGradientBoostingClassifier, StackingClassifier, VotingClassifier, ExtraTreesClassifier
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold(n_splits=2, shuffle=True, random_state=1)
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

model1 = LogisticRegression()
model2 = SVC()
model3 = GradientBoostingClassifier()
model4 = RandomForestClassifier()

ensemble = StackingClassifier(estimators=[('lr', model1), ('svc', model2), ('gbc', model3), ('rf', model4)],
                            final_estimator=LogisticRegression())

ensemble.fit(X_train, y_train)
y_pred = ensemble.predict(X_test)
print("Confusion Matrix: ", confusion_matrix(y_test, y_pred))
print("Classification Report: ", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:  [[12047   313]
#  [ 2052  1868]]
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91     12360
#            1       0.86      0.48      0.61      3920
#
#     accuracy                           0.85     16280
#    macro avg       0.86      0.73      0.76     16280
# weighted avg       0.85      0.85      0.84     16280

# %%
skf = StratifiedKFold(n_splits=2, shuffle=True, random_state=5)
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

model1 = ExtraTreesClassifier()
model2 = RandomForestClassifier()
model3 = SVC()
model4 = LogisticRegression()

ensemble = VotingClassifier(estimators=[('etc', model1), ('rfc', model2), ('svc', model3), ('lr', model4)])
ensemble.fit(X_train, y_train)
y_pred = ensemble.predict(X_test)
print("Confusion Matrix: ", confusion_matrix(y_test, y_pred))
print("Classification Report: ", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:  [[11876   484]
#  [ 1916  2004]]
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91     12360
#            1       0.81      0.51      0.63      3920
#
#     accuracy                           0.85     16280
#    macro avg       0.83      0.74      0.77     16280
# weighted avg       0.85      0.85      0.84     16280

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
pred = nb.predict(X_test)

# %%
print(confusion_matrix(pred, y_test))
print(classification_report(pred, y_test))
# Out:
# [[11536  2710]
#  [  824  1210]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87     14246
#            1       0.31      0.59      0.41      2034
#
#     accuracy                           0.78     16280
#    macro avg       0.62      0.70      0.64     16280
# weighted avg       0.86      0.78      0.81     16280

# %%
df['avg_hours_per_day'] = df['hours.per.week']/7

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90   Private   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66   Private  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.to_csv('frame_updated.csv', index=False)

# %%
sns.countplot(df['income'])
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='income', ylabel='count'>

# %%
from imblearn.over_sampling import ADASYN

# %%
adasyn = ADASYN(sampling_strategy='minority')
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.20,
                                                                    random_state=1)

# %%
logreg = LogisticRegression(max_iter=10000)
logreg.fit(X_train, y_train)
pred = logreg.predict(X_test)

# %%
print(confusion_matrix(pred, y_test))
print(classification_report(pred, y_test))
# Out:
# [[3690  426]
#  [1275 4411]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81      4116
#            1       0.91      0.78      0.84      5686
#
#     accuracy                           0.83      9802
#    macro avg       0.83      0.84      0.83      9802
# weighted avg       0.84      0.83      0.83      9802

# %%
etc = ExtraTreesClassifier()
etc.fit(X_train, y_train)
pred = etc.predict(X_test)

# %%
print(confusion_matrix(pred, y_test))
print(classification_report(pred, y_test))
# Out:
# [[4297  512]
#  [ 668 4325]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      4809
#            1       0.89      0.87      0.88      4993
#
#     accuracy                           0.88      9802
#    macro avg       0.88      0.88      0.88      9802
# weighted avg       0.88      0.88      0.88      9802

# %%
reg = RandomForestClassifier()
reg.fit(X_train, y_train)
pred = reg.predict(X_test)

# %%
print(confusion_matrix(pred, y_test))
print(classification_report(pred, y_test))
# Out:
# [[4309  439]
#  [ 656 4398]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      4748
#            1       0.91      0.87      0.89      5054
#
#     accuracy                           0.89      9802
#    macro avg       0.89      0.89      0.89      9802
# weighted avg       0.89      0.89      0.89      9802

# %%
import optuna
import numpy as np
from functools import partial
from sklearn.metrics import accuracy_score

# %%
def optimize(trail, X, y):
    criterion = trail.suggest_categorical('criterion', ['gini', 'entropy'])
    n_estimators = trail.suggest_int('n_estimators', 100, 1500)
    max_depth = trail.suggest_int('max_depth', 3, 15)
    max_features = trail.suggest_float('max_features', 0.01, 1.0)
    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        max_features=max_features,
        criterion=criterion
    )
    skf = StratifiedKFold(n_splits=2)
    accuracies = []
    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        accuracy = accuracy_score(y_test, preds)
        accuracies.append(accuracy)
    return -1.0 * np.mean(accuracies)

# %%
optimization_function = partial(optimize, X=X, y=y)
study = optuna.create_study(direction='minimize')
study.optimize(optimization_function, n_trials=15)
# Out:
# [I 2023-03-18 08:53:28,047] A new study created in memory with name: no-name-ecd4bd05-b9a0-427f-b5b8-410da96a375d
# [I 2023-03-18 08:53:32,493] Trial 0 finished with value: -0.8194462252090776 and parameters: {'criterion': 'entropy', 'n_estimators': 165, 'max_depth': 6, 'max_features': 0.764828678879343}. Best is trial 0 with value: -0.8194462252090776.
# [I 2023-03-18 08:53:39,344] Trial 1 finished with value: -0.8234694799578713 and parameters: {'criterion': 'entropy', 'n_estimators': 226, 'max_depth': 15, 'max_features': 0.4337389532068387}. Best is trial 1 with value: -0.8234694799578713.
# [I 2023-03-18 08:53:49,347] Trial 2 finished with value: -0.819814739735967 and parameters: {'criterion': 'gini', 'n_estimators': 509, 'max_depth': 6, 'max_features': 0.6144505882169649}. Best is trial 1 with value: -0.8234694799578713.
# ...
